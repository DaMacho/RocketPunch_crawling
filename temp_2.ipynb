# %% [markdown]
# ## This is temporary file to make crawling program

# %% [markdown]
# Work by bs4
#
# - not working well.

# %% [markdown]
# ### Objective

# %% [markdown]
# Build a crawling program to get job infomation from **rocketpunch.com**.
# - Because I am looking for job.
#
# Practice my crawling skill.
# - One good practice to code everyday.
# - May good project to fill my portfolio.
#
# Just for fun with productive life.

# %% [markdown]
# **4 major componets**
#
# - Action module (crawling)
# - Data access object 1 (mysql)
# - Data access object 2 (mongodb)
# - configuration module (personal info)

# %%
import requests
from bs4 import BeautifulSoup

import time

import datetime
print(datetime.datetime.now())
# Out:
# 2017-11-18 23:48:31.011415

# %% [raw]
# from rckpdao import RckpDAO
# from rckpdao_mongo import save_rckp

# %% [raw]
# # getting address by number of pages
# # search condition : Entry level jobs with keywords(머신러닝, machine learning, data, python, machine-learning, data-analysis)
# # can change search criteria by modifying url
#
# adds = []
# for i in range(1,20):
#     address = "https://www.rocketpunch.com/jobs?career_type=1&keywords=머신러닝&keywords=machine%20learning&keywords=data&keywords=python&keywords=machine-learning&keywords=data-analysis&page={}&q=".format(i)
#     adds.append(address)
# print(adds)

# %%
adds = ["https://www.rocketpunch.com/jobs?career_type=1&keywords=머신러닝&keywords=machine%20learning&keywords=data&keywords=python&keywords=machine-learning&keywords=data-analysis&page={}&q=".format(i) for i in range(1,5)]
print(adds)
# Out:
# ['https://www.rocketpunch.com/jobs?career_type=1&keywords=머신러닝&keywords=machine%20learning&keywords=data&keywords=python&keywords=machine-learning&keywords=data-analysis&page=1&q=', 'https://www.rocketpunch.com/jobs?career_type=1&keywords=머신러닝&keywords=machine%20learning&keywords=data&keywords=python&keywords=machine-learning&keywords=data-analysis&page=2&q=', 'https://www.rocketpunch.com/jobs?career_type=1&keywords=머신러닝&keywords=machine%20learning&keywords=data&keywords=python&keywords=machine-learning&keywords=data-analysis&page=3&q=', 'https://www.rocketpunch.com/jobs?career_type=1&keywords=머신러닝&keywords=machine%20learning&keywords=data&keywords=python&keywords=machine-learning&keywords=data-analysis&page=4&q=']

# %% [markdown]
# <br>

# %%
address = "https://www.rocketpunch.com/jobs?career_type=1&keywords=머신러닝&keywords=machine%20learning&keywords=data&keywords=python&keywords=machine-learning&keywords=data-analysis&page=1&q="

# %%
res = requests.get(address)
content = res.content

soup = BeautifulSoup(content, 'html5lib')

comps = soup.find(id = 'company-list')

soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]>
# <html xmlns:fb="http://ogp.me/ns/fb#" class="ie ie9">
# <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html xmlns:fb="http://ogp.me/ns/fb#"><!--<![endif]--><head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <title>채용 정보
#  | 로켓펀치 - 스타트업 네트워크</title>
#   <meta content="width=device-width, initial-scale = 1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="RocketPunch Inc." name="author"/>
#   <meta content="나에게 꼭 맞는 채용 정보를 찾아보세요. '로켓펀치'는 비즈니스와 커리어를 성장시킬 수 있는 국내 최대 비즈니스 네트워크입니다." name="description"/>
#   <meta content=" 로켓펀치, RocketPunch, 비즈니스, business, 네트워크, network, 데이터베이스, database, 프로필, profile, 이력서, resume, cv, 전문가, professional, 창업, 사업, 벤처, 스타트업, startup, 회사, 기업, company, 채용, 일자리, job, 구인, 구직, hr, 리크루팅, recruiting, 투자, investment, 인수, 합병, m&amp;a, merger and acquisition" name="keywords"/>
# <link href="https://www.rocketpunch.com/jobs" rel="canonical"/>
#   <link href="https://static.rocketpunch.com/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="https://static.rocketpunch.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="https://static.rocketpunch.com/bundle/rocketpunch.7e542de335c2c8e8ac73.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/pikaday/1.5.1/css/pikaday.min.css" rel="stylesheet"/>
#   <link href="https://static.rocketpunch.com/bundle/search.7e542de335c2c8e8ac73.css" rel="stylesheet" type="text/css"/>
#   <link href="https://static.rocketpunch.com/bundle/job.7e542de335c2c8e8ac73.css" rel="stylesheet" type="text/css"/>
#   <script>addEventListener('error', window.__e=function f(e){f.q=f.q||[];f.q.push(e)});</script>
#
#     <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
# })(window,document.documentElement,'async-hide','dataLayer',4000,
# {'GTM-NMJNJ4X':true});</script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://static.rocketpunch.com/bundle/analytics.e058c3fe28e9ec6fac4f.js" type="text/javascript"></script>
#   <script src="https://widget.uservoice.com/AimAPibQeGuNzX3w7vJ7Q.js" type="text/javascript"></script>
# </head>
# <body class="pushable"><div id="global-messages"></div>
# <div id="old_alert"></div>
# <script>
#   window.fbAsyncInit = function() {
#     FB.init({
#       appId      : '440667109316276',
#       xfbml      : true,
#       version    : 'v2.7'
#     });
#   };
#   (function(d, s, id){
#      var js, fjs = d.getElementsByTagName(s)[0];
#      if (d.getElementById(id)) {return;}
#      js = d.createElement(s); js.id = id;
#      js.src = "//connect.facebook.net/en_US/sdk.js";
#      fjs.parentNode.insertBefore(js, fjs);
#    }(document, 'script', 'facebook-jssdk'));
# </script>
# <div class="ui vertical menu left sidebar" id="main-sidebar">
#   <div class="sidebar-header clearfix">
#     <a id="close-main-sidebar"><i class="big ic-close icon" title="RocketPunch"></i></a>
#     <a href="/" style="float:right;"><i class="big blue ic-rocketpunch_bi icon" title="RocketPunch"></i></a>
#   </div>
#   <a class="item" href="/people">네트워크</a>
#   <a class="item" href="/companies">기업</a>
#   <a class="item" href="/jobs">채용</a>
#   <a class="item" href="/collections">컬렉션</a>
#   <a class="item" href="/pricing">서비스</a>
#   <a class="item" href="https://blog.rocketpunch.com" target="_blank">블로그</a>
# </div>
# <div class="pusher">
#   <div class="ui white attached borderless main menu" id="header">
#     <div class="ui container">
#       <div class="tablet mobile only" id="mobile-menu">
#         <a class="item" id="mobile-main-menu">
#           <i class="large ic-menu icon menu-icon"></i>
#         </a>
#         <a class="item" id="mobile-search-menu">
#           <i class="large ic-magnifying-glass icon"></i>
#         </a><div class="right menu">
#             <a class="item" data-modal="signup"><strong>무료 가입</strong></a>
#             <a class="item" data-modal="login"><strong>로그인</strong></a>
#           </div></div><div class="computer large screen widescreen only">
#         <a class="main logo item" href="/">
#           <i class="big blue ic-rocketpunch_bi icon" id="rocketpunch-icon" title="RocketPunch"></i>
#         </a>
#         <div class="divider item"><div class="ui vertical divider"></div></div>
#         <div class="item">
#           <div class="ui search" data-url="/suggest?q={query}" id="header-search">
#             <div class="ui left icon transparent input">
#               <i class="ic-magnifying-glass icon"></i>
#               <input class="prompt" placeholder="통합 검색" size="20" type="text"/>
#             </div>
#           </div>
#         </div>
#       </div>
#       <div class="right menu">
#         <a class="item" href="/people">네트워크</a>
#         <a class="item" href="/companies">기업</a>
#         <a class="item" href="/jobs">채용</a>
#         <a class="item" href="/collections">컬렉션</a>
#         <a class="item" href="/pricing">서비스</a>
#         <a class="item" href="https://blog.rocketpunch.com" target="_blank">블로그</a>
#         <a class="item" data-modal="signup"><strong>무료 가입</strong></a>
#         <a class="item" data-modal="login"><strong>로그인</strong></a>
#       </div></div>  </div>  <div class="ui container" id="breadcrumb"><div class="ui mini breadcrumb">
#   <a class="section" href="/">홈</a>
#   <div class="divider"> / </div>
#   <a class="section" href="/jobs">채용</a>
# </div></div>
#
# <div class="ui container" id="wrap">
#   <div class="ui tablet stackable grid">
#     <div class="three wide column">
#       <div class="tablet mobile only">
#         <div class="ui navigation selection fluid dropdown" id="mobile-navigation">
#           <i class="dropdown icon"></i>
#           <div class="ui default blue text">            <i class="ic-envelope icon"></i>모든 채용 (318)
# </div>
#           <div class="menu">
#             <a class="item" href="/jobs">
#               <i class="ic-envelope icon"></i>모든 채용 정보 (318)
#             </a>
#             <a class="item" href="/jobs/collections">
#               <i class="ic-envelopes icon"></i>투자사 별 채용 정보 (857)
#             </a>
#             <a class="item" href="/jobs?rel=skipped">
#               <i class="ic-box_misc icon"></i>
#               Skip한 채용 정보</a>
#           </div>
#         </div>
#       </div>
#       <div class="computer large screen widescreen only" id="desktop-navigation"><a class="ui primary fluid button" data-modal="signup">채용 무료 등록</a><div class="ui fluid vertical menu" id="object-list-menu">
#           <a class="active item" href="/jobs">
#             <i class="ic-envelope icon"></i>
#             모든 채용 정보 (318)
#           </a>
#           <a class="item" href="/jobs/collections">
#             <i class="ic-envelopes icon"></i>투자사 별 채용 정보 (857)
#           </a>
#           <a class="item" data-modal="signup" data-next="/jobs?rel=skipped">
#             <i class="ic-box_misc icon"></i>
#             Skip한 채용 정보
#           </a>
#         </div>
#           <div id="section-banners">
#             <div class="ui loading advertisement" id="banner-list">
#             </div>
#             <p class="banner guide">
#               <a class="primary link" href="/pricing" target="_blank">배너 문의</a>
#             </p>
#           </div>
#       </div>
#     </div>
#
#     <div class="nine wide column">
# <div class="ui segment omnibox-filter">
#   <h5 class="ui top header">
#     채용 정보 검색
#   </h5>
#
#   <form action="/jobs" id="search-form" method="GET">
#     <div class="ui doubling stackable menu">
# <div class="ui dropdown item">
#   <div class="ui basic button">
#     채용 분야
#     <i class="ic-chevron-down icon"></i>
#   </div>
#   <div class="menu">
#       <a class="item" data-caption="SW 개발" data-name="job" data-value="sw-developer" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;job=sw-developer&amp;page=1&amp;career_type=1">SW 개발</a>
#       <a class="item" data-caption="HW 개발" data-name="job" data-value="hw-developer" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;job=hw-developer&amp;page=1&amp;career_type=1">HW 개발</a>
#       <a class="item" data-caption="디자인" data-name="job" data-value="designer" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;job=designer&amp;page=1&amp;career_type=1">디자인</a>
#       <a class="item" data-caption="운영" data-name="job" data-value="manager" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;job=manager&amp;page=1&amp;career_type=1">운영</a>
#       <a class="item" data-caption="마케팅" data-name="job" data-value="marketer" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;job=marketer&amp;page=1&amp;career_type=1">마케팅</a>
#       <a class="item" data-caption="비즈니스" data-name="job" data-value="business_dev" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;job=business_dev&amp;page=1&amp;career_type=1">비즈니스</a>
#       <a class="item" data-caption="투자" data-name="job" data-value="investor" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;job=investor&amp;page=1&amp;career_type=1">투자</a>
#       <a class="item" data-caption="경영지원" data-name="job" data-value="management-support" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;job=management-support&amp;page=1&amp;career_type=1">경영지원</a>
#   </div>
# </div><div class="ui dropdown item">
#   <div class="ui basic button">
#     산업
#     <i class="ic-chevron-down icon"></i>
#   </div>
#   <div class="menu">
#     <div class="ui search" data-caption="산업: " data-name="tag" data-url="/api/search/companies/tags?name={query}">
#       <div class="ui icon fluid input">
#         <input class="industry prompt" placeholder="산업을 검색해보세요" type="text"/>
#         <i class="search icon"></i>
#       </div>
#       <div class="results">
#       </div>
#       <div class="presets">
#         <p class="search category">인기 산업</p>
#           <a class="item result" data-caption="웹서비스" data-name="tag" data-value="웹서비스" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;tag=%EC%9B%B9%EC%84%9C%EB%B9%84%EC%8A%A4&amp;page=1&amp;career_type=1">
#             <div class="content">
#               <div class="title">
#                 웹서비스
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="모바일" data-name="tag" data-value="모바일" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;tag=%EB%AA%A8%EB%B0%94%EC%9D%BC&amp;page=1&amp;career_type=1">
#             <div class="content">
#               <div class="title">
#                 모바일
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="e-commerce" data-name="tag" data-value="e-commerce" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;tag=e-commerce&amp;page=1&amp;career_type=1">
#             <div class="content">
#               <div class="title">
#                 e-commerce
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="IoT" data-name="tag" data-value="IoT" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;tag=IoT&amp;page=1&amp;career_type=1">
#             <div class="content">
#               <div class="title">
#                 IoT
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="O2O" data-name="tag" data-value="O2O" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;tag=O2O&amp;page=1&amp;career_type=1">
#             <div class="content">
#               <div class="title">
#                 O2O
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="핀테크" data-name="tag" data-value="핀테크" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;tag=%ED%95%80%ED%85%8C%ED%81%AC&amp;page=1&amp;career_type=1">
#             <div class="content">
#               <div class="title">
#                 핀테크
#               </div>
#             </div>
#           </a>
#       </div>
#     </div>
#   </div>
# </div><div class="ui dropdown item">
#   <div class="ui basic button">
#     전문 분야
#     <i class="ic-chevron-down icon"></i>
#   </div>
#   <div class="menu">
#     <div class="ui search" data-caption="전문 분야: " data-name="tag" data-url="/api/search/jobs/specialties?name={query}">
#       <div class="ui icon fluid input">
#         <input class="industry prompt" placeholder="전문 분야를 검색해보세요" type="text"/>
#         <i class="search icon"></i>
#       </div>
#       <div class="results">
#       </div>
#       <div class="presets">
#           <a class="item result" data-caption="전문 분야: Android" data-name="specialty" data-value="Android" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=Android">
#             <div class="content">
#               <div class="title">
#                 Android
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="전문 분야: iOS" data-name="specialty" data-value="iOS" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=iOS">
#             <div class="content">
#               <div class="title">
#                 iOS
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="전문 분야: C++" data-name="specialty" data-value="C++" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=C%2B%2B">
#             <div class="content">
#               <div class="title">
#                 C++
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="전문 분야: C#" data-name="specialty" data-value="C#" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=C%23">
#             <div class="content">
#               <div class="title">
#                 C#
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="전문 분야: Java" data-name="specialty" data-value="Java" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=Java">
#             <div class="content">
#               <div class="title">
#                 Java
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="전문 분야: PHP" data-name="specialty" data-value="PHP" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=PHP">
#             <div class="content">
#               <div class="title">
#                 PHP
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="전문 분야: Python" data-name="specialty" data-value="Python" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=Python">
#             <div class="content">
#               <div class="title">
#                 Python
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="전문 분야: Ruby" data-name="specialty" data-value="Ruby" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=Ruby">
#             <div class="content">
#               <div class="title">
#                 Ruby
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="전문 분야: JSP" data-name="specialty" data-value="JSP" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=JSP">
#             <div class="content">
#               <div class="title">
#                 JSP
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="전문 분야: Node.js" data-name="specialty" data-value="Node.js" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=Node.js">
#             <div class="content">
#               <div class="title">
#                 Node.js
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="전문 분야: AngularJS" data-name="specialty" data-value="AngularJS" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=AngularJS">
#             <div class="content">
#               <div class="title">
#                 AngularJS
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="전문 분야: jQuery" data-name="specialty" data-value="jQuery" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=jQuery">
#             <div class="content">
#               <div class="title">
#                 jQuery
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="전문 분야: ASP.NET" data-name="specialty" data-value="ASP.NET" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;specialty=ASP.NET">
#             <div class="content">
#               <div class="title">
#                 ASP.NET
#               </div>
#             </div>
#           </a>
#       </div>
#     </div>
#   </div>
# </div><div class="ui dropdown item with-range">
#   <div class="ui basic button">
#     보상
#     <i class="ic-chevron-down icon"></i>
#   </div>
#   <div class="menu">
#     <div class="ui header" style="min-width: 20em; font-size: 14px;">
#       <div>
#         <p>
#           <input checked="" id="salary" type="checkbox"/>
#           <label for="salary">연봉:</label>
#         </p>
#         <div class="ui range" data-caption="연봉:" data-format="format_salary" data-max="200" data-min="0"></div>
#         <p><span data-caption="연봉: 0-" data-name="salary" data-value="0-" style="float: right">0억-2억+</span></p>
#       </div>
#       <div style="margin-top:2em; margin-bottom:2em;">
#         <p>
#           <input checked="" id="stock" type="checkbox"/>
#           <label for="stock">스톡옵션:
#         </label></p>
#         <div class="ui range" data-caption="스톡옵션:" data-format="format_stock" data-max="50" data-min="0"></div>
#         <p><span data-caption="스톡옵션: 0-" data-name="stock" data-value="0-" style="float: right">0%-5%</span></p>
#       </div>
#     </div>
#     <a class="item button">필터 적용하기</a>
#   </div>
# </div><div class="ui dropdown item">
#   <div class="ui basic button">
#     채용 조건
#     <i class="ic-chevron-down icon"></i>
#   </div>
#   <div class="menu">
#     <p class="search category">경력 여부</p>
#     <a class="item" data-caption="경력 여부: 신입" data-name="career_type" data-value="1" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;career_type=1">신입</a>
#     <a class="item" data-caption="경력 여부: 경력" data-name="career_type" data-value="2" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;career_type=2">경력</a>
#     <a class="item" data-caption="경력 여부: 인턴" data-name="career_type" data-value="4" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;career_type=4">인턴</a>
#     <p class="search category">근무 조건</p>
#     <a class="item" data-caption="원격 근무: Y" data-name="remote" data-value="1" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;remote=1&amp;page=1&amp;career_type=1">원격 근무</a>
#     <p class="search category">외국어 조건</p>
#     <a class="item" data-caption="언어: 영어" data-name="language" data-value="영어" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;language=%EC%98%81%EC%96%B4&amp;page=1&amp;career_type=1">영어</a>
#     <a class="item" data-caption="언어: 중국어" data-name="language" data-value="중국어" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;language=%EC%A4%91%EA%B5%AD%EC%96%B4&amp;page=1&amp;career_type=1">중국어</a>
#     <a class="item" data-caption="언어: 일본어" data-name="language" data-value="일본어" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;language=%EC%9D%BC%EB%B3%B8%EC%96%B4&amp;page=1&amp;career_type=1">일본어</a>
#     <p class="search category">병역대체</p>
#     <a class="item" data-caption="병역대체 기업: Y" data-name="military_service" data-value="1" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;military_service=1">병역대체 기업</a>
#   </div>
# </div><div class="ui location dropdown item">
#   <div class="ui basic button">
#     지역
#     <i class="ic-chevron-down icon"></i>
#   </div>
#   <div class="menu">
#     <div class="ui search" data-caption="지역: " data-name="location" data-url="/api/search/jobs/locations?name={query}">
#       <div class="ui icon fluid input">
#         <input class="location prompt" placeholder="지역을 검색해보세요" type="text"/>
#         <i class="search icon"></i>
#       </div>
#       <div class="results">
#       </div>
#       <div class="presets">
#         <p class="search category">인기 지역</p>
#           <a class="item result" data-caption="서울특별시 강남구" data-name="location" data-value="서울특별시 강남구" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;location=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EA%B0%95%EB%82%A8%EA%B5%AC">
#             <div class="content">
#               <div class="title">
#                 서울특별시 강남구
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="경기도 성남시" data-name="location" data-value="경기도 성남시" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;location=%EA%B2%BD%EA%B8%B0%EB%8F%84+%EC%84%B1%EB%82%A8%EC%8B%9C">
#             <div class="content">
#               <div class="title">
#                 경기도 성남시
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="서울특별시 마포구" data-name="location" data-value="서울특별시 마포구" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;location=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EB%A7%88%ED%8F%AC%EA%B5%AC">
#             <div class="content">
#               <div class="title">
#                 서울특별시 마포구
#               </div>
#             </div>
#           </a>
#           <a class="item result" data-caption="서울특별시 구로구" data-name="location" data-value="서울특별시 구로구" href="/jobs?keywords=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&amp;keywords=machine+learning&amp;keywords=data&amp;keywords=python&amp;keywords=machine-learning&amp;keywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1&amp;location=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EA%B5%AC%EB%A1%9C%EA%B5%AC">
#             <div class="content">
#               <div class="title">
#                 서울특별시 구로구
#               </div>
#             </div>
#           </a>
#       </div>
#     </div>
#   </div>
# </div>    </div>
#
#     <div class="search-omnibox">
#       <div class="search-filters">
#
#
#
#
#
#
#           <a class="ui label" data-short-caption="신입">
#     경력 여부: 신입
# <input id="id_career_type_0" name="career_type" type="hidden" value="1"/>    <i class="delete icon"></i>
#   </a>
#
#
#
#
#
#           <a class="ui label" data-short-caption="머신러닝">
#     머신러닝
# <input id="id_keywords_0" name="keywords" type="hidden" value="머신러닝"/>    <i class="delete icon"></i>
#   </a>
#   <a class="ui label" data-short-caption="machine learning">
#     machine learning
# <input id="id_keywords_1" name="keywords" type="hidden" value="machine learning"/>    <i class="delete icon"></i>
#   </a>
#   <a class="ui label" data-short-caption="data">
#     data
# <input id="id_keywords_2" name="keywords" type="hidden" value="data"/>    <i class="delete icon"></i>
#   </a>
#   <a class="ui label" data-short-caption="python">
#     python
# <input id="id_keywords_3" name="keywords" type="hidden" value="python"/>    <i class="delete icon"></i>
#   </a>
#   <a class="ui label" data-short-caption="machine-learning">
#     machine-learning
# <input id="id_keywords_4" name="keywords" type="hidden" value="machine-learning"/>    <i class="delete icon"></i>
#   </a>
#   <a class="ui label" data-short-caption="data-analysis">
#     data-analysis
# <input id="id_keywords_5" name="keywords" type="hidden" value="data-analysis"/>    <i class="delete icon"></i>
#   </a>
#
#       </div>
#       <div class="ui fluid input">
#         <input id="id_q" name="q" placeholder="필터, 키워드, 기업 이름 검색" type="text"/>
#         <button class="ui primary mini button search" id="search-button" style="margin-left: -3000px" type="submit">검색</button>
#       </div>
#     </div>
#   </form>
#
# <div class="ui blank segment" data-url="/api/jobs/user_filter" id="user_filters">
#
#   <div class="ui right floated menu">
#     <div class="right menu">
#       <div class="item">
#         <div class="ui form" data-modal="signup" id="user_filter_form">
#           <button class="ui right floated basic small button">
#             검색 조건 저장
#           </button>
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <br style="clear:both"/>
#
# </div></div>
# <div id="search-results">
#   <div class="ui blank segment loading">
#     <img src="https://static.rocketpunch.com/images/company/preload_company_result.png"/>
#   </div>
# </div>
#     </div>
#   </div>
# </div>
#
# <div aria-hidden="true" aria-labelledby="관리자 등록" class="ui modal fade" id="request-company-admin-modal">
#   <div class="ui center aligned header">
#     <i class="ic-close icon"></i>
#     <p>관리자 등록 안내</p>
#   </div>
#   <div class="content">
#     <p>관리자로 등록 후 채용 정보를 등록 할 수 있습니다.</p>
#     <p><a href="https://www.rocketpunch.com/help/1446005182" style="text-decoration:underline;" target="_blank">구성원으로 등록한 기업의 관리자에게 문의하시거나, 로켓펀치 관리자에게 문의해주세요.</a></p>
#   </div>
# </div>
#   <div class="ui footer segment" id="footer">
#     <div class="ui container">
#       <div class="ui stackable mobile reversed grid">
#         <div class="left floated nine wide footer column">
#           <div class="ui horizontal small link list">
#             <a class="item" href="https://www.rocketpunch.com/companies/rocketpunch" target="_blank">회사소개</a>
#             <a class="item" href="/about">서비스소개</a>
#             <a class="item" href="/tos">이용약관</a>
#             <a class="item" href="/privacy">개인정보취급방침</a>
#             <a class="item" href="/security">보안 취약점 보고</a>
#             <a class="item" href="/email_security">이메일 무단수집거부</a>
#             <a class="item" href="/partnership">협업 제안</a>
#             <a class="item" href="/help">도움말</a>
#             <a class="item" href="/pricing">유료서비스 안내</a>
#           </div>
#         </div>
#         <div class="right floated three wide sns column">
#           <div class="ui horizontal large link list">
#             <a class="item" href="http://www.facebook.com/pages/RocketPunch/155413834600029" target="_blank" title="로켓펀치 페이스북">
#               <i class="ic-social-facebook large icon"></i>
#             </a>
#             <a class="item" href="https://twitter.com/rocketpun_ch" target="_blank" title="로켓펀치 트위터">
#               <i class="ic-social-twitter large icon"></i>
#             </a>
#             <a class="item" href="https://plus.google.com/113619534078613762472" target="_blank" title="로켓펀치 구글플러스">
#               <i class="ic-social-googleplus large icon"></i>
#             </a>
#             <a class="item" href="http://blog.naver.com/rocketpun_ch" target="_blank" title="로켓펀치 블로그">
#               <i class="ic-social-naver large icon"></i>
#             </a>
#           </div>
#         </div>
#       </div>
#       <p class="ui grey text company info">
#         <small>© Since 2012, RocketPunch, Inc.  All rights reserved. <br/>직업정보제공사업신고 J1206020160003</small>
#       </p>
#     </div>
#   </div>
# </div>
# <input id="next_url" type="hidden"/>
# <!-- signup -->
# <div aria-hidden="true" aria-labelledby="로켓펀치 회원가입" class="ui modal fade signup" id="signup-modal">
#   <div class="ui center aligned header">
#     <i class="ic-close icon"></i>
#     <p>무료 가입</p>
#   </div>
#     <div class="content">
# <div class="modal-description">
#   당신의 성장에 필요한 사람과 기회가 로켓펀치에 있습니다.
# </div>
# <div class="ui stackable social-connect grid">
#   <div class="six wide column">
#     <a class="fluid ui facebook button" href="/login/facebook/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1">
#       <i class="facebook icon"></i>
# Facebook으로 가입
#     </a>
#   </div>
#   <div class="six wide column">
#     <a class="fluid ui google plus button" href="/login/google-oauth2/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1">
#       <i class="google plus icon"></i>
# Google으로 가입
#     </a>
#   </div>
#   <div class="six wide column">
#     <a class="fluid ui linkedin button" href="/login/linkedin-oauth2/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1">
#       <i class="linkedin icon"></i>
# LinkedIn으로 가입
#     </a>
#   </div>
#   <div class="six wide column">
#     <a class="fluid ui github button" href="/login/github/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1">
#       <i class="github icon"></i>
# GitHub으로 가입
#     </a>
#   </div>
# </div>
# <div class="ui basic center aligned login segment">
#   <p>또는 이메일로 회원가입하기</p>
# </div>
# <form action="/api/users/register" class="ui equal width form" id="form-signup-inline" method="post" name="signup-inline">
# <input name="csrfmiddlewaretoken" type="hidden" value="atYL4Y7YJn3Eoc6M7bxgN90GdtTsSpE9iJIS4BzCIx8OCDAaMlc2MLTGY8TydCoJ"/>  <input name="_method" type="hidden" value="post"/>
#   <div class="fields">
#     <div class="field">
#       <label for="id-last_name">성</label>
#       <input data-required="성을 입력해주세요" id="id-last_name" name="last_name" placeholder="성" required="" type="text"/>
#     </div>
#     <div class="field">
#       <label for="id-first_name">이름</label>
#       <input data-required="이름을 입력해주세요" id="id-first_name" name="first_name" placeholder="이름" required="" type="text"/>
#     </div>
#   </div>
#   <div class="field">
#     <label for="id-email">E-mail</label>
#     <input data-required="E-mail을 입력해주세요" data-validate="E-mail 형식을 확인해주세요." id="id-email" name="email" placeholder="이메일 ex) rocket@email.com" required="" type="email"/>
#   </div>
#   <div class="field">
#     <label for="id-password">비밀번호</label>
#     <input data-required="비밀번호를 입력해주세요" id="id-password" name="password" placeholder="비밀번호" required="" type="password"/>
#     <p class="support">
#       회원가입시 로켓펀치의 <a href="/tos" target="_blank">이용약관</a>, <a href="/privacy" target="_blank">개인정보취급방침</a>을 읽고 이해하셨으며 해당 내용에 동의하신 것이 됩니다.
#     </p>
#   </div>
#   <div style="text-align:center">
#     <button class="ui primary button" data-done="가입 성공" data-ing="가입 중..." data-retry="재시도" type="submit">무료 가입</button>
#   </div>
# </form>
# <div class="ui basic center aligned segment">
#   <span>이미 로켓펀치 회원이라면</span>
#   <a class="primary link" data-modal="login">로그인</a>
# </div>  </div>
# </div>
# <!-- login -->
# <div aria-hidden="true" aria-labelledby="로켓펀치 로그인" class="ui modal fade login" id="login-modal">
#   <div class="ui center aligned header">
#     <i class="ic-close icon"></i>
#     <p>로그인</p>
#   </div>
#   <div class="content">
# <div class="modal-description">
#   당신의 성장에 필요한 사람과 기회가 로켓펀치에 있습니다.
# </div>
# <div class="ui stackable social-connect grid">
#   <div class="six wide column">
#     <a class="fluid ui facebook button" href="/login/facebook/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1">
#       <i class="facebook icon"></i>
# Facebook으로 로그인
#     </a>
#   </div>
#   <div class="six wide column">
#     <a class="fluid ui google plus button" href="/login/google-oauth2/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1">
#       <i class="google plus icon"></i>
# Google으로 로그인
#     </a>
#   </div>
#   <div class="six wide column">
#     <a class="fluid ui linkedin button" href="/login/linkedin-oauth2/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1">
#       <i class="linkedin icon"></i>
# LinkedIn으로 로그인
#     </a>
#   </div>
#   <div class="six wide column">
#     <a class="fluid ui github button" href="/login/github/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1">
#       <i class="github icon"></i>
# GitHub으로 로그인
#     </a>
#   </div>
# </div>
# <div class="ui basic center aligned login segment">
#   <p>또는 이메일로 로그인하기</p>
# </div>
# <form action="/api/users/login" class="ui form" id="form-login-inline" method="post" name="login-inline">
# <input name="csrfmiddlewaretoken" type="hidden" value="atYL4Y7YJn3Eoc6M7bxgN90GdtTsSpE9iJIS4BzCIx8OCDAaMlc2MLTGY8TydCoJ"/>  <input name="_method" type="hidden" value="post"/><div class="field">
#     <label for="id-email">E-mail</label>
#     <input data-required="E-mail을 입력해주세요" data-validate="E-mail 형식을 확인해주세요." id="id-email" name="email" placeholder="이메일 ex) rocket@email.com" required="" type="email"/>
#   </div>
#   <div class="field">
#     <label for="id-password">비밀번호</label>
#     <input data-required="비밀번호를 입력해주세요" id="id-password" name="password" placeholder="비밀번호" required="" type="password"/>
#     <p class="support">
#       <a class="primary link" data-modal="reset">비밀번호 찾기</a>
#     </p>
#   </div>
#   <div style="text-align:center">
#     <button class="ui primary button" data-done="로그인 성공" data-ing="로그인 중..." data-retry="재시도" type="submit">로그인</button>
#   </div>
# </form>
# <div class="ui basic center aligned segment">
#   <span>계정이 없다면 로켓펀치에 가입해보세요!</span>
#   <a class="primary link" data-modal="signup">무료 가입</a>
# </div>  </div>
# </div>
# <!-- reset -->
# <div aria-hidden="true" aria-labelledby="로켓펀치 비밀번호 재설정" class="ui modal fade reset" id="reset-modal">
#   <div class="ui center aligned header">
#     <i class="ic-close icon"></i>
#     <p>비밀번호 재설정</p>
#   </div>
#   <div class="content">
# <div class="ui basic center aligned segment">
#   <p>가입하신 E-mail을 입력해주세요</p>
# </div>
# <form action="/api/password_reset" class="ui form" id="form-password-reset" method="post" name="password-reset">
# <input name="csrfmiddlewaretoken" type="hidden" value="atYL4Y7YJn3Eoc6M7bxgN90GdtTsSpE9iJIS4BzCIx8OCDAaMlc2MLTGY8TydCoJ"/>  <input name="_method" type="hidden" value="post"/>
#   <div class="field">
#     <label for="id-email">E-mail</label>
#     <input data-required="E-mail을 입력해주세요" data-validate="E-mail 형식을 확인해주세요." id="id-reset-email" name="email" placeholder="이메일 ex) rocket@email.com" required="" type="email"/>
#   </div>
#   <div style="text-align:center">
#     <button class="ui primary button" type="submit">비밀번호 재설정 이메일 발송</button>
#   </div>
# </form>  </div>
# </div>
# <div aria-hidden="true" aria-labelledby="프로필 완성도 안내" class="ui profile-progress modal fade" id="fill_user_profile-modal">
#   <i class="close ic-close"></i>
#   <div class="content">
# <p style="text-align: center"><em>프로필 완성도</em>가 부족합니다.</p>
#
#
#   </div>
# </div>
# <div class="ui modal" id="mobile-search-modal"><div class="ui huge fluid search" data-url="/suggest?q={query}" id="header-search-mobile">
#   <div class="ui huge fluid input">
#     <i class="ic-chevron-left icon"></i>
#
#     <input class="prompt" placeholder="통합 검색" type="text"/>
#   </div>
# </div></div>
# <div class="ui modal" id="fb-like-modal">
#   <div style="position:relative;"><i class="ic-close icon"></i></div>
#   <div class="content">
#     <div class="title">페이스북에서 당신을 성장시킬 이야기를 만나보세요!</div>
#     <img src="https://static.rocketpunch.com/images/common/popup-header%402x.jpg" width="100%"/>
#     <div class="fb-page" data-adapt-container-width="true" data-hide-cover="true" data-href="https://www.facebook.com/rocketpunch.inc/?fref=ts" data-show-facepile="true" data-small-header="true" data-width="272px"><blockquote cite="https://www.facebook.com/rocketpunch.inc/?fref=ts" class="fb-xfbml-parse-ignore"><a href="https://www.facebook.com/rocketpunch.inc/?fref=ts">로켓펀치 - 스타트업 네트워크</a></blockquote></div>
#   </div>
# </div>
# <script>
# var ie8 = false, old_browser = false;if (document.createElement('input').placeholder == undefined) { old_browser = true;}
# </script>
# <!--[if lt IE 9]>
# <script>ie8 = true;</script>
# <script src="https://static.rocketpunch.com/js/ie8.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.2/html5shiv.min.js"></script>
# <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
# <script src="https://static.rocketpunch.com/js/respond.min.js"></script>
# <link href="https://static.rocketpunch.com/js/respond-proxy.html" id="respond-proxy" rel="respond-proxy" />
# <link href="/static/img/respond.proxy.gif" id="respond-redirect" rel="respond-redirect" />
# <script src="/static/js/respond.proxy.js"></script>
# <![endif]-->
# <!--[if IE]>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/flexibility/2.0.1/flexibility.js"></script>
# <![endif]-->
# <!--[if gt IE 9]>
# old_browser = false;
# <![endif]-->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery.form/3.51/jquery.form.min.js" type="text/javascript"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.2.12/semantic.min.js" type="text/javascript"></script>
# <script src="https://developers.kakao.com/sdk/js/kakao.min.js"></script>
# <script>
# var signupUrl = '/signup';
# var csrftoken = 'atYL4Y7YJn3Eoc6M7bxgN90GdtTsSpE9iJIS4BzCIx8OCDAaMlc2MLTGY8TydCoJ';
# var is_mobile = false;var is_mobile_log = 'is_mobile';if(!is_mobile) is_mobile_log = 'not_mobile';
# Kakao.init('79663be4ff6e7ab77ad6558da7511642');
# $rocket = {}, loader = '<div id="$rocketLoader" class="ui active inverted dimmer"><div class="ui text loader">Loading</div></div>';
# var is_authenticated = false;
# $rocket.is_authenticated = is_authenticated;
#
# $.fn.search.settings.error.noResults = "검색 결과가 없습니다.";
# $.fn.search.settings.error.serverError = "검색 결과 출력에 문제가 있습니다. 관리자에게 문의해 주세요.";
# </script>
# <script src="https://static.rocketpunch.com/bundle/polyfill.46e6f2948fd32e020cdc.js" type="text/javascript"></script>
# <script src="https://static.rocketpunch.com/bundle/base.f653762d3653dd9157ed.js" type="text/javascript"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.17.1/moment.min.js"></script>
# <script src="https://static.rocketpunch.com/js/pikaday.js"></script>
# <script src="https://static.rocketpunch.com/js/jquery.cookie.js"></script>
# <script>
# $rocket.search_translations = {
#   'collection': "컬렉션",
#   'company': "기업",
#   'job': "채용",
#   'school': "학교",
#   'user': "네트워크",
#   '_all': "{}에 대한 전체 결과"
# }
# $(function(){
#   if (!(/Android|webOS|iPhone|iPad|iPod|BlackBerry/i.test(navigator.userAgent))) {
#     if (typeof UserVoice != 'undefined') {
#       UserVoice.push(['set', {
#         accent_color: '#448dd6',
#         trigger_color: 'white',
#         trigger_background_color: 'rgba(46, 49, 51, 0.6)'
#       }]);
#       UserVoice.push(['identify', {}]);
#       UserVoice.push(['addTrigger', { mode: 'contact', trigger_position: 'bottom-right' }]);
#       UserVoice.push(['autoprompt', {}]);
#     }
#   }
#   if ($.cookie('fb_like_modal')) {
#   } else {
#     $(window).on('scroll.fblikemodal', $rocket.fbLikeCheckScroll);
#   }
# });
# </script>
# <script src="https://static.rocketpunch.com/bundle/job.e92e6154e1abb48b4e68.js" type="text/javascript"></script>
# <script>
# var $rocketSearch = {
#   settings: {
#     url: {
#       list: "/jobs",
#       template: "/api/jobs/template"
#     },
#     format_salary: function(low, high) {
#       var value = String(low * 1000000) + '-', name = '';
#       if( high < 200 ) value += String(high * 1000000);
#       name += ( low > 0 ) ? ($rocket.intComma(100 * low) + '만') : String(100 * low);
#       name += '-';
#       name += $rocket.intComma(100 * high) + '만';
#       return {
#         name: name,
#         value: value
#       };
#     },
#     format_stock: function(low, high) {
#       var value = String(low / 10.) + '-', name = '';
#       if( high < 50 ) value += String(high / 10.);
#       name += ( low > 0 ) ? (String(low / 10.) + '%') : String(low / 10.);
#       name += '-';
#       name += ( high < 50 ) ? (String(high / 10.) + '%') : (String(high / 10.) + '%+');
#       return {
#         name: name,
#         value: value
#       };
#     },
#     templates: {
#       save_filter_button: function (data, $button, query_string, filter_name) {
#         var $plus_button = $button.find('.icon.button');
#         $button.removeClass('transition');
#         $button.find('.label.disabled').removeClass('disabled');
#         $plus_button.removeClass('loading');
#         $button.addClass('transition');
#         $button.data('url', "/api/jobs/user_filter/0".replace('0', data.user_filter.id));
#         $button.find('.ui.label').html(
#           '<a href="/jobs?' + query_string + '">' + filter_name + '</a>'
#         );
#         return $button;
#       },
#       save_filter_popup: function(data) {
#         return $('<div />')
#           .addClass('ui popup')
#           .html(
#             '<div class="ui form">' +
#               '<div class="ui checkbox">' +
#                 '<input id="is_sent_mail_' + data.user_filter.id + '" name="is_sent_mail" type="checkbox" checked>' +
#                 '<label for="is_sent_mail_' + data.user_filter.id + '">새 채용 정보 등록 알림</label>' +
#               '</div>' +
#             '</div>' +
#             '<div class="ui form">이 검색조건을 <div class="ui red mini delete button">삭제</div>'
#           );
#       }
#     },
#     messages: {
#       confirm_delete_user_filter: "정말로 삭제하시겠습니까?"
#     }
#   }
# };
# $rocket.initList();
# </script>
# <script src="https://static.rocketpunch.com/bundle/search.f7ca64d8f579296fc87b.js" type="text/javascript"></script>
# <script>
# var isBannerLoad = false;
# function bannerLoadEvent() {
#   if (isBannerLoad) {
# ga('send', 'event', 'banner', 'job list load', 'job list banner load, Seoultp-Business-20171023-500x500', 1, {nonInteraction: true});ga('send', 'event', 'banner', 'job list load', 'job list banner load, Fastcampus-School-20171026-500x500', 1, {nonInteraction: true});ga('send', 'event', 'banner', 'job list load', 'job list banner load, Innobiz-Business-20170910-500x500', 1, {nonInteraction: true});ga('send', 'event', 'banner', 'job list load', 'job list banner load, Innerlink-Partnership-20170622-500x500', 1, {nonInteraction: true});  }
#   var job_ads = $('.job-ad-item');
#   for(var i=0;i<job_ads.length;i++) {
#     ga('send', 'event', 'advertisement', 'job list ad load', 'job list ad load, ' + $(job_ads[i]).data('banner_id'), 1, {nonInteraction: true});
#   }
#   isBannerLoad = true;
# }
#
# $rocketSearch.refresh();
# $().ready(function(){
#   $('#mobile-navigation').dropdown({delay : {touch: 300}});
#   $('#mobile-navigation').off('touchstart touchstart.dropdown');
#   if ($('#manage-job').length) {
#     $('#manage-job').dropdown({delay : {touch: 300}});
#     $('#manage-job').off('touchstart touchstart.dropdown');
#   }
#   $rocketSearch.init($('.omnibox-filter'));
#
#   $('*[data-modal="request-company-admin"]').on('click', function(){
#     $('#request-company-admin-modal').modal('show');
#     return false;
#   });
#
# var banners = [];
#   var $frame = $('#banner-list');
# banners.push('<div class="banner"><a href="https://www.rocketpunch.com/seoultp-2017" title="새창" target="_blank" id="Seoultp-Business-20171023-500x500"><img src="https://media.rocketpunch.com/recruit_banner/2017/10/23/Seoultp-Business-20171023-500x500.png" alt="" class="ui fluid image"></div></a>');banners.push('<div class="banner"><a href="http://school.fastcampus.co.kr/mktg_dms/?utm_source=rocketpunch&utm_medium=banner&utm_campaign=mktg_dms_10" title="새창" target="_blank" id="Fastcampus-School-20171026-500x500"><img src="https://media.rocketpunch.com/recruit_banner/2017/10/26/Fastcampus-School-20171026-500x500.png" alt="" class="ui fluid image"></div></a>');banners.push('<div class="banner"><a href="http://bit.ly/2uYDa4o" title="새창" target="_blank" id="Innobiz-Business-20170910-500x500"><img src="https://media.rocketpunch.com/recruit_banner/2017/09/10/Innobiz-Business-20170910-500x500.png" alt="" class="ui fluid image"></div></a>');banners.push('<div class="banner"><a href="https://goo.gl/forms/SjVO5MYwvyFxsP4U2" title="새창" target="_blank" id="Innerlink-Partnership-20170622-500x500"><img src="https://media.rocketpunch.com/recruit_banner/2017/06/23/Innerlink-Partnership-20170622-500x500.png" alt="" class="ui fluid image"></div></a>');  setTimeout(function(){
#     $('#banner-list').attr("class", "ui advertisement");
#     for(var i = 0, max = banners.length; i<max; i++) {
#       $frame.append(banners[i]);
#     }
# ga('send', 'event', 'banner', 'job list load', 'job list banner load, Seoultp-Business-20171023-500x500', 1, {nonInteraction: true});ga('send', 'event', 'banner', 'job list load', 'job list banner load, Fastcampus-School-20171026-500x500', 1, {nonInteraction: true});ga('send', 'event', 'banner', 'job list load', 'job list banner load, Innobiz-Business-20170910-500x500', 1, {nonInteraction: true});ga('send', 'event', 'banner', 'job list load', 'job list banner load, Innerlink-Partnership-20170622-500x500', 1, {nonInteraction: true});    $(document).on('click', '#banner-list a', function(e){
#       ga('send', 'event', 'banner', 'job list click', 'job list banner click '+$(this).attr('id'), 1);
#     });
#   }, 10);
#   $(document).on('click', '.job-ad-group a', function(e){
#     ga('send', 'event', 'advertisement', 'job list ad click', 'job list ad click, ' + $(this).data('click'), 1, {nonInteraction: true});
#   });
# });
# </script>
# <div class="ui small modal" id="job_signup_popup">
#   <div style="position:relative;"><i class="ic-close icon"></i></div>
#   <div class="content">
#     <div class="default-content" style="text-align:center;">
#       <div class="logo image" style="margin:40px 0;">
#         <i class="big blue ic-rocketpunch_bi icon" id="rocketpunch-icon" style="font-size:56px" title="RocketPunch"></i>
#       </div>
#       <div style="font-size:18px;margin-bottom:32px;">
#         로켓펀치에 가입하고 <span style="font-weight:700;">318개가 넘는 채용 정보</span>를 만나보세요!
#       </div>
#       <a class="fluid ui facebook popup-signup button" data-signup_type="facebook" href="/login/facebook/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1" style="margin-bottom:20px;">
#         <i class="facebook icon"></i>
# Facebook으로 가입
#       </a>
#       <a class="ui primary link" id="signup_popup_option">그 외 로그인 옵션</a>
#     </div>
#     <div class="option-content" style="display:none;padding-bottom:20px;">
#       <div class="logo image" style="margin-bottom:5px;text-align:center;">
#         <i class="big blue ic-rocketpunch_bi icon" id="rocketpunch-icon" style="font-size:56px" title="RocketPunch"></i>
#       </div>
#       <form action="/api/users/login" class="ui form" id="form-login-inline" method="post" name="login-inline">
# <input name="csrfmiddlewaretoken" type="hidden" value="atYL4Y7YJn3Eoc6M7bxgN90GdtTsSpE9iJIS4BzCIx8OCDAaMlc2MLTGY8TydCoJ"/>        <input name="_method" type="hidden" value="post"/>
#         <div class="field">
#           <label for="id-email">E-mail</label>
#           <input data-required="E-mail을 입력해주세요" data-validate="E-mail 형식을 확인해주세요." id="id-email" name="email" placeholder="이메일 ex) rocket@email.com" required="" type="email"/>
#         </div>
#         <div class="field">
#           <label for="id-password">비밀번호</label>
#           <input data-required="비밀번호를 입력해주세요" id="id-password" name="password" placeholder="비밀번호" required="" type="password"/>
#           <p class="support">
#             <a class="primary link" data-modal="reset">비밀번호 찾기</a>
#           </p>
#         </div>
#         <div style="text-align:center">
#           <button class="ui primary popup-signup button" data-done="로그인 성공" data-ing="로그인 중..." data-retry="재시도" data-signup_type="login" type="submit">로그인</button>
#         </div>
#       </form>
#       <div class="ui basic center aligned login segment">
#         <p>SNS 계정으로 로그인</p>
#       </div>
#       <div class="ui stackable social-connect grid">
#         <div class="six wide column">
#           <a class="fluid ui facebook popup-signup button" data-signup_type="facebook" href="/login/facebook/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1">
#             <i class="facebook icon"></i>
# Facebook          </a>
#         </div>
#         <div class="six wide column">
#           <a class="fluid ui google plus popup-signup button" data-signup_type="google-oauth2" href="/login/google-oauth2/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1">
#             <i class="google plus icon"></i>
# Google          </a>
#         </div>
#         <div class="six wide column">
#           <a class="fluid ui linkedin popup-signup button" data-signup_type="linkedin-oauth2" href="/login/linkedin-oauth2/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1">
#             <i class="linkedin icon"></i>
# LinkedIn          </a>
#         </div>
#         <div class="six wide column">
#           <a class="fluid ui github popup-signup button" data-signup_type="github" href="/login/github/?next=/jobs%3Fkeywords=data-analysis&amp;q=&amp;page=1&amp;career_type=1">
#             <i class="github icon"></i>
# GitHub          </a>
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
# <script type="text/javascript">
# $(function(){
#   $rocket.scrollSignupPopup('job', 2);
# });
# </script>
# <div id="old_contents" style="display:none;">
#   <div class="ui error message" role="alert">
#     <div class="ui container grid">
#       <div class="left floated left aligned six wide column">안전하고 원활한 서비스 이용을 위해 브라우저를 업데이트 해주세요.</div>
#       <div class="right floated right aligned six wide column">
#         <a class="negative ui button" href="https://support.google.com/chrome/answer/95346?hl=ko" target="_blank">구글 크롬 안내</a>
#         <a class="negative ui button" href="http://windows.microsoft.com/ko-kr/internet-explorer/download-ie" target="_blank">최신 IE 안내</a>
#       </div>
#     </div>
#   </div>
# </div>
#
# </body></html>
